# %% [markdown]
# # SFDM

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.lines as plt2

# %%
b=np.loadtxt('explanatory00_background.dat', unpack=True)

# %%
plt.loglog(b[0],b[10]/[13])
plt.show()

# %%
plt.plot(b[0],b[16])
plt.show()
